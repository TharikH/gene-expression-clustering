# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
! cat zeisel_2015_pc.csv | tr "," "." | tr ";" "," > zeisel_2016_pc.csv
# Out:
# cat: zeisel_2015_pc.csv: No such file or directory

# %%
zeisel_pc = pd.read_csv("zeisel_2016_pc.csv")
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 zeisel_pc = pd.read_csv("zeisel_2016_pc.csv")
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py:610, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     605 kwds_defaults = _refine_defaults_read(
# ...

# %%
X = np.array(zeisel_pc.iloc[:, 1:])

# %%
X[np.isnan(X)] = 0

# %%
x = np.array(zeisel_pc["PC1"])
y = np.array(zeisel_pc["PC2"])
n_clusters = 9
k_means = KMeans(n_clusters=n_clusters, random_state=0, init='k-means++').fit(X)
# Out:
# /home/kramasamy90/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.scatter(x, y, c=k_means.labels_)

# %%
from sklearn.manifold import TSNE
X_tsne = TSNE(n_components=2).fit_transform(X)

# %%
X_tsne.shape
x = X_tsne[:, 0]
y = X_tsne[:, 1]
plt.scatter(x, y, c = k_means.labels_, cmap='tab20b')
